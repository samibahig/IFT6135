# %% [markdown]
# <a href="https://colab.research.google.com/github/samibahig/IFT6135/blob/main/Assignement2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !python run_exp.py  --model=TRANSFORMER --optimizer=ADAM --initial_lr=0.0001 --batch_size=128 --seq_len=35 --hidden_size=512  --num_layers=2 --dp_keep_prob=0.9 --num_epochs=20
# Out:
# python3: can't open file 'run_exp.py': [Errno 2] No such file or directory

# %%
 # !python run_exp.py  --model=GRU --optimizer=ADAM --initial_lr=0.001 --batch_size=128 --seq_len=35 --hidden_size=512 --num_layers=4 --dp_keep_prob=0.5  --num_epochs=20
# Out:
# ########## Setting Up Experiment ######################
#
# Putting log in GRU_ADAM_model=GRU_optimizer=ADAM_initial_lr=0.001_batch_size=128_seq_len=35_hidden_size=512_num_layers=4_dp_keep_prob=0.5_num_epochs=20_0
# Using the GPU
# Loading data from data
#   vocabulary size: 10000
#
# ########## Running Main Loop ##########################
#
# EPOCH 0 ------------------
# step: 10	loss (sum over all examples' seen this epoch):3051.4411187171936	speed (wps):9587.056609771813
# step: 30	loss (sum over all examples' seen this epoch):7806.392388343811	speed (wps):9814.166574900073
# step: 50	loss (sum over all examples' seen this epoch):12462.487607002258	speed (wps):9836.661935875301
# step: 70	loss (sum over all examples' seen this epoch):17014.482312202454	speed (wps):9874.353784605832
# step: 90	loss (sum over all examples' seen this epoch):21486.895956993103	speed (wps):9890.929797943047
# ...

# %%
# !python run_exp.py  --optimizer=ADAM --initial_lr=0.001 --batch_size=128 --seq_len=35 --hidden_size=512 --num_layers=2 --dp_keep_prob=0.5  --num_epochs=20 --save_best
# Out:
# ########## Setting Up Experiment ######################
#
# Putting log in GRU_ADAM_optimizer=ADAM_initial_lr=0.001_batch_size=128_seq_len=35_hidden_size=512_num_layers=2_dp_keep_prob=0.5_num_epochs=20_save_best_0
# Using the GPU
# Loading data from data
#   vocabulary size: 10000
#
# ########## Running Main Loop ##########################
#
# EPOCH 0 ------------------
# Traceback (most recent call last):
#   File "run_exp.py", line 449, in <module>
#     train_ppl, train_loss = run_epoch(model, train_data, True, lr)
#   File "run_exp.py", line 404, in run_epoch
#     loss.backward()
#   File "/usr/local/lib/python3.6/dist-packages/torch/tensor.py", line 195, in backward
#     torch.autograd.backward(self, gradient, retain_graph, create_graph)
#   File "/usr/local/lib/python3.6/dist-packages/torch/autograd/__init__.py", line 99, in backward
#     allow_unreachable=True)  # allow_unreachable flag
# ...

# %%
# !python run_exp.py  --optimizer=SGD  --initial_lr=10.0  --batch_size=128 --seq_len=35 --hidden_size=512 --num_layers=2 --dp_keep_prob=0.5  --num_epochs=20
# Out:
# ########## Setting Up Experiment ######################
#
# Putting log in GRU_SGD_optimizer=SGD_initial_lr=10.0_batch_size=128_seq_len=35_hidden_size=512_num_layers=2_dp_keep_prob=0.5_num_epochs=20_0
# Using the GPU
# Loading data from data
#   vocabulary size: 10000
#
# ########## Running Main Loop ##########################
#
# EPOCH 0 ------------------
# step: 10	loss (sum over all examples' seen this epoch):3494.05305147171	speed (wps):20962.837948000837
# step: 30	loss (sum over all examples' seen this epoch):8950.311744213104	speed (wps):21882.20858244874
# step: 50	loss (sum over all examples' seen this epoch):14138.612351417542	speed (wps):22146.47543199876
# step: 70	loss (sum over all examples' seen this epoch):19119.5174407959	speed (wps):22209.969858350043
# step: 90	loss (sum over all examples' seen this epoch):24003.65370988846	speed (wps):22214.579609584056
# step: 110	loss (sum over all examples' seen this epoch):28797.16255426407	speed (wps):22166.102092575835
# ...

# %% [markdown]
# # New Section

# %% [markdown]
# # New Section

# %% [markdown]
# # New Section
